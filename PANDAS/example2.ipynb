# %%
import pandas as pd

# %%
df = pd.read_csv("Z:/Training Data For ML/nyc_weather.csv")
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df["Temperature"].min()
# Out:
# 20

# %%
df["EST"][df["Temperature"] > 30]
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 19    1/20/2016
# 20    1/21/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df["Humidity"].mean()
# Out:
# 51.67741935483871

# %%
df["WindSpeedMPH"].fillna(0,inplace = True)

# %%
df["WindSpeedMPH"].mean()
# Out:
# 6.225806451612903

# %%
type(df["Humidity"])
# Out:
# pandas.core.series.Series

# %%
# df.drop("level_0",axis = 1,inplace = True)
# df

# %%
# df.reset_index(inplace = True)
df.tail(30)
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 1         1      1   1/2/2016           36        18        46
# 2         2      2   1/3/2016           40        21        47
# 3         3      3   1/4/2016           25         9        44
# 4         4      4   1/5/2016           20        -3        41
# 5         5      5   1/6/2016           33         4        35
# 6         6      6   1/7/2016           39        11        33
# 7         7      7   1/8/2016           39        29        64
# 8         8      8   1/9/2016           44        38        77
# 9         9      9  1/10/2016           50        46        71
# 10       10     10  1/11/2016           33         8        37
# 11       11     11  1/12/2016           35        15        53
# 12       12     12  1/13/2016           26         4        42
# 13       13     13  1/14/2016           30        12        47
# 14       14     14  1/15/2016           43        31        62
# ...

# %%
df["Events"].fillna("No event", inplace = True)

# %%
df
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 0         0      0   1/1/2016           38        23        52
# 1         1      1   1/2/2016           36        18        46
# 2         2      2   1/3/2016           40        21        47
# 3         3      3   1/4/2016           25         9        44
# 4         4      4   1/5/2016           20        -3        41
# 5         5      5   1/6/2016           33         4        35
# 6         6      6   1/7/2016           39        11        33
# 7         7      7   1/8/2016           39        29        64
# 8         8      8   1/9/2016           44        38        77
# 9         9      9  1/10/2016           50        46        71
# 10       10     10  1/11/2016           33         8        37
# 11       11     11  1/12/2016           35        15        53
# 12       12     12  1/13/2016           26         4        42
# 13       13     13  1/14/2016           30        12        47
# ...

# %%
X = df.iloc[0:20,0:4]
X
# Out:
#     level_0  index        EST  Temperature
# 0         0      0   1/1/2016           38
# 1         1      1   1/2/2016           36
# 2         2      2   1/3/2016           40
# 3         3      3   1/4/2016           25
# 4         4      4   1/5/2016           20
# 5         5      5   1/6/2016           33
# 6         6      6   1/7/2016           39
# 7         7      7   1/8/2016           39
# 8         8      8   1/9/2016           44
# 9         9      9  1/10/2016           50
# 10       10     10  1/11/2016           33
# 11       11     11  1/12/2016           35
# 12       12     12  1/13/2016           26
# 13       13     13  1/14/2016           30
# 14       14     14  1/15/2016           43
# 15       15     15  1/16/2016           47
# 16       16     16  1/17/2016           36
# 17       17     17  1/18/2016           25
# 18       18     18  1/19/2016           22
# 19       19     19  1/20/2016           32

# %%
y = df.iloc[20:40,0:8]
y
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 20       20     20  1/21/2016           31        11        45
# 21       21     21  1/22/2016           26         6        41
# 22       22     22  1/23/2016           26        21        78
# 23       23     23  1/24/2016           28        11        53
# 24       24     24  1/25/2016           34        18        54
# 25       25     25  1/26/2016           43        29        56
# 26       26     26  1/27/2016           41        22        45
# 27       27     27  1/28/2016           37        20        51
# 28       28     28  1/29/2016           36        21        50
# 29       29     29  1/30/2016           34        16        46
# 30       30     30  1/31/2016           46        28        52
#
#     Sea Level PressureIn  VisibilityMiles
# 20                 30.15               10
# 21                 30.21                9
# 22                 29.77                1
# ...

# %%
pd.concat([X,y])
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 0         0      0   1/1/2016           38       NaN       NaN
# 1         1      1   1/2/2016           36       NaN       NaN
# 2         2      2   1/3/2016           40       NaN       NaN
# 3         3      3   1/4/2016           25       NaN       NaN
# 4         4      4   1/5/2016           20       NaN       NaN
# 5         5      5   1/6/2016           33       NaN       NaN
# 6         6      6   1/7/2016           39       NaN       NaN
# 7         7      7   1/8/2016           39       NaN       NaN
# 8         8      8   1/9/2016           44       NaN       NaN
# 9         9      9  1/10/2016           50       NaN       NaN
# 10       10     10  1/11/2016           33       NaN       NaN
# 11       11     11  1/12/2016           35       NaN       NaN
# 12       12     12  1/13/2016           26       NaN       NaN
# 13       13     13  1/14/2016           30       NaN       NaN
# ...

# %%
new =pd.concat([X,y], keys=["one","two"])
new
# Out:
#         level_0  index        EST  Temperature  DewPoint  Humidity  \
# one 0         0      0   1/1/2016           38       NaN       NaN
#     1         1      1   1/2/2016           36       NaN       NaN
#     2         2      2   1/3/2016           40       NaN       NaN
#     3         3      3   1/4/2016           25       NaN       NaN
#     4         4      4   1/5/2016           20       NaN       NaN
#     5         5      5   1/6/2016           33       NaN       NaN
#     6         6      6   1/7/2016           39       NaN       NaN
#     7         7      7   1/8/2016           39       NaN       NaN
#     8         8      8   1/9/2016           44       NaN       NaN
#     9         9      9  1/10/2016           50       NaN       NaN
#     10       10     10  1/11/2016           33       NaN       NaN
#     11       11     11  1/12/2016           35       NaN       NaN
#     12       12     12  1/13/2016           26       NaN       NaN
# ...

# %%
new.loc["two"]
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 20       20     20  1/21/2016           31      11.0      45.0
# 21       21     21  1/22/2016           26       6.0      41.0
# 22       22     22  1/23/2016           26      21.0      78.0
# 23       23     23  1/24/2016           28      11.0      53.0
# 24       24     24  1/25/2016           34      18.0      54.0
# 25       25     25  1/26/2016           43      29.0      56.0
# 26       26     26  1/27/2016           41      22.0      45.0
# 27       27     27  1/28/2016           37      20.0      51.0
# 28       28     28  1/29/2016           36      21.0      50.0
# 29       29     29  1/30/2016           34      16.0      46.0
# 30       30     30  1/31/2016           46      28.0      52.0
#
#     Sea Level PressureIn  VisibilityMiles
# 20                 30.15             10.0
# 21                 30.21              9.0
# 22                 29.77              1.0
# ...

# %%
new_ =pd.merge(new,y)

# %%
new_
# Out:
#     level_0  index        EST  Temperature  DewPoint  Humidity  \
# 0        20     20  1/21/2016           31      11.0      45.0
# 1        21     21  1/22/2016           26       6.0      41.0
# 2        22     22  1/23/2016           26      21.0      78.0
# 3        23     23  1/24/2016           28      11.0      53.0
# 4        24     24  1/25/2016           34      18.0      54.0
# 5        25     25  1/26/2016           43      29.0      56.0
# 6        26     26  1/27/2016           41      22.0      45.0
# 7        27     27  1/28/2016           37      20.0      51.0
# 8        28     28  1/29/2016           36      21.0      50.0
# 9        29     29  1/30/2016           34      16.0      46.0
# 10       30     30  1/31/2016           46      28.0      52.0
#
#     Sea Level PressureIn  VisibilityMiles
# 0                  30.15             10.0
# 1                  30.21              9.0
# 2                  29.77              1.0
# ...
