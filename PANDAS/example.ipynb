# %%
import pandas as pd

# %%
df = pd.read_csv("Z:/Training Data For ML/advertising.csv")

# %%
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
help(pd.arrays)
# Out:
# Help on package pandas.arrays in pandas:
#
# NAME
#     pandas.arrays - All of pandas' ExtensionArrays.
#
# DESCRIPTION
#     See :ref:`extending.extension-types` for more.
#
# PACKAGE CONTENTS
#
#
# CLASSES
#     numpy.lib.mixins.NDArrayOperatorsMixin(builtins.object)
#         pandas.core.arrays.numpy_.PandasArray(pandas.core.arrays.base.ExtensionArray, pandas.core.arrays.base.ExtensionOpsMixin, numpy.lib.mixins.NDArrayOperatorsMixin)
#             pandas.core.arrays.string_.StringArray
#     pandas._libs.interval.IntervalMixin(builtins.object)
#         pandas.core.arrays.interval.IntervalArray(pandas._libs.interval.IntervalMixin, pandas.core.arrays.base.ExtensionArray)
#     pandas.core.arrays.base.ExtensionArray(builtins.object)
#         pandas.core.arrays.categorical.Categorical(pandas.core.arrays.base.ExtensionArray, pandas.core.base.PandasObject)
#         pandas.core.arrays.interval.IntervalArray(pandas._libs.interval.IntervalMixin, pandas.core.arrays.base.ExtensionArray)
# ...

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
df.tail()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                             Ad Topic Line           City  Male  \
# 995         Fundamental modular algorithm      Duffystad     1
# 996       Grass-roots cohesive monitoring    New Darlene     1
# 997          Expanded intangible solution  South Jessica     1
# 998  Proactive bandwidth-monitored policy    West Steven     0
# 999       Virtual 5thgeneration emulation    Ronniemouth     0
#
#                     Country            Timestamp  Clicked on Ad
# 995                 Lebanon  2016-02-11 21:49:00              1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
help(pd.util)
# Out:
# Help on package pandas.util in pandas:
#
# NAME
#     pandas.util
#
# PACKAGE CONTENTS
#     _decorators
#     _depr_module
#     _doctools
#     _exceptions
#     _print_versions
#     _test_decorators
#     _tester
#     _validators
#     testing
#
# FUNCTIONS
#     __getattr__(name)
#
# FILE
#     c:\users\reliance\anaconda3\lib\site-packages\pandas\util\__init__.py

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
df["Area Income"]
# Out:
# 0      61833.90
# 1      68441.85
# 2      59785.94
# 3      54806.18
# 4      73889.99
#          ...
# 995    71384.57
# 996    67782.17
# 997    42415.72
# 998    41920.79
# 999    29875.80
# Name: Area Income, Length: 1000, dtype: float64

# %%
df.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
X = df[["Age","Area Income","Daily Internet Usage"]]
X
# Out:
#      Age  Area Income  Daily Internet Usage
# 0     35     61833.90                256.09
# 1     31     68441.85                193.77
# 2     26     59785.94                236.50
# 3     29     54806.18                245.89
# 4     35     73889.99                225.58
# ..   ...          ...                   ...
# 995   30     71384.57                208.58
# 996   45     67782.17                134.42
# 997   51     42415.72                120.37
# 998   19     41920.79                187.95
# 999   26     29875.80                178.35
#
# [1000 rows x 3 columns]

# %%
X_ = df.iloc[0:10,1:6]
# it returns the rows from 0 to 10 and columns from 1 to 6
X_
# Out:
#    Age  Area Income  Daily Internet Usage  \
# 0   35     61833.90                256.09
# 1   31     68441.85                193.77
# 2   26     59785.94                236.50
# 3   29     54806.18                245.89
# 4   35     73889.99                225.58
# 5   23     59761.56                226.74
# 6   33     53852.85                208.36
# 7   48     24593.33                131.76
# 8   30     68862.00                221.51
# 9   20     55642.32                183.82
#
#                            Ad Topic Line              City
# 0     Cloned 5thgeneration orchestration       Wrightburgh
# 1     Monitored national standardization         West Jodi
# 2       Organic bottom-line service-desk          Davidton
# 3  Triple-buffered reciprocal time-frame    West Terrifurt
# 4          Robust logistical utilization      South Manuel
# 5        Sharable client-driven software         Jamieberg
# 6             Enhanced dedicated support       Brandonstad
# ...

# %%
X__ = df.iloc[0:10,[0,2,3,4]]
X__
# Out:
#    Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                     68.95     61833.90                256.09
# 1                     80.23     68441.85                193.77
# 2                     69.47     59785.94                236.50
# 3                     74.15     54806.18                245.89
# 4                     68.37     73889.99                225.58
# 5                     59.99     59761.56                226.74
# 6                     88.91     53852.85                208.36
# 7                     66.00     24593.33                131.76
# 8                     74.53     68862.00                221.51
# 9                     69.88     55642.32                183.82
#
#                            Ad Topic Line
# 0     Cloned 5thgeneration orchestration
# 1     Monitored national standardization
# 2       Organic bottom-line service-desk
# 3  Triple-buffered reciprocal time-frame
# 4          Robust logistical utilization
# ...

# %%
# to create column in the datafram
X__["New_column"] = 1
X__
# Out:
#    Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                     68.95     61833.90                256.09
# 1                     80.23     68441.85                193.77
# 2                     69.47     59785.94                236.50
# 3                     74.15     54806.18                245.89
# 4                     68.37     73889.99                225.58
# 5                     59.99     59761.56                226.74
# 6                     88.91     53852.85                208.36
# 7                     66.00     24593.33                131.76
# 8                     74.53     68862.00                221.51
# 9                     69.88     55642.32                183.82
#
#                            Ad Topic Line  New_column
# 0     Cloned 5thgeneration orchestration           1
# 1     Monitored national standardization           1
# 2       Organic bottom-line service-desk           1
# 3  Triple-buffered reciprocal time-frame           1
# ...

# %%
X__["(daily time on site)*(daily internet usage)"] = X__["Daily Time Spent on Site"]*X__["Daily Internet Usage"]

# %%
X__
# Out:
#    Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                     68.95     61833.90                256.09
# 1                     80.23     68441.85                193.77
# 2                     69.47     59785.94                236.50
# 3                     74.15     54806.18                245.89
# 4                     68.37     73889.99                225.58
# 5                     59.99     59761.56                226.74
# 6                     88.91     53852.85                208.36
# 7                     66.00     24593.33                131.76
# 8                     74.53     68862.00                221.51
# 9                     69.88     55642.32                183.82
#
#                            Ad Topic Line  New_column  \
# 0     Cloned 5thgeneration orchestration           1
# 1     Monitored national standardization           1
# 2       Organic bottom-line service-desk           1
# 3  Triple-buffered reciprocal time-frame           1
# ...

# %%
X__["new"] = "--pre--"+X__["Ad Topic Line"].str.upper() + "--post--"
X__
# Out:
#    Daily Time Spent on Site  Area Income  Daily Internet Usage  \
# 0                     68.95     61833.90                256.09
# 1                     80.23     68441.85                193.77
# 2                     69.47     59785.94                236.50
# 3                     74.15     54806.18                245.89
# 4                     68.37     73889.99                225.58
# 5                     59.99     59761.56                226.74
# 6                     88.91     53852.85                208.36
# 7                     66.00     24593.33                131.76
# 8                     74.53     68862.00                221.51
# 9                     69.88     55642.32                183.82
#
#                            Ad Topic Line  New_column  \
# 0     Cloned 5thgeneration orchestration           1
# 1     Monitored national standardization           1
# 2       Organic bottom-line service-desk           1
# 3  Triple-buffered reciprocal time-frame           1
# ...

# %%
X__.describe()
# Out:
#        Daily Time Spent on Site   Area Income  Daily Internet Usage  \
# count                  10.00000     10.000000             10.000000
# mean                   72.04800  58146.992000            213.002000
# std                     8.01593  13536.970162             36.137003
# min                    59.99000  24593.330000            131.760000
# 25%                    68.51500  55015.215000            197.417500
# 50%                    69.67500  59773.750000            223.545000
# 75%                    74.43500  66789.862500            234.060000
# max                    88.91000  73889.990000            256.090000
#
#        New_column  (daily time on site)*(daily internet usage)
# count        10.0                                    10.000000
# mean          1.0                                 15346.693780
# std           0.0                                  2979.031739
# min           1.0                                  8696.160000
# ...

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
# if we want the record of all the woman with age greater than 30
Y = df[(df["Age"] > 30) & (df["Male"] == 0)]
Y
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 4                       68.37   35     73889.99                225.58
# 6                       88.91   33     53852.85                208.36
# 10                      47.64   49     45632.51                122.02
# 14                      42.95   33     30976.00                143.56
# ..                        ...  ...          ...                   ...
# 981                     76.58   46     41884.64                258.26
# 982                     54.37   38     72196.29                140.77
# 985                     72.88   44     64011.26                125.12
# 989                     70.96   31     55187.85                256.40
# 992                     69.17   40     66193.81                123.62
#
#                            Ad Topic Line             City  Male  \
# ...

# %%
# if we want to know the details of the youngest woman
age = df[(df["Age"] == df["Age"].min()) & (df["Male"] ==0)]
age
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 349                     60.91   19     53309.61                184.94
# 998                     55.55   19     41920.79                187.95
#
#                             Ad Topic Line               City  Male    Country  \
# 349  Upgradable directional system engine  Port Kathleenfort     0      Nauru
# 998  Proactive bandwidth-monitored policy        West Steven     0  Guatemala
#
#                Timestamp  Clicked on Ad
# 349  2016-06-09 14:24:06              1
# 998  2016-03-24 02:35:54              0

# %%
df["Country"].unique()
# Out:
# array(['Tunisia', 'Nauru', 'San Marino', 'Italy', 'Iceland', 'Norway',
#        'Myanmar', 'Australia', 'Grenada', 'Ghana', 'Qatar', 'Burundi',
#        'Egypt', 'Bosnia and Herzegovina', 'Barbados', 'Spain',
#        'Palestinian Territory', 'Afghanistan',
#        'British Indian Ocean Territory (Chagos Archipelago)',
#        'Russian Federation', 'Cameroon', 'Korea', 'Tokelau', 'Monaco',
#        'Tuvalu', 'Greece', 'British Virgin Islands',
#        'Bouvet Island (Bouvetoya)', 'Peru', 'Aruba', 'Maldives',
#        'Senegal', 'Dominica', 'Luxembourg', 'Montenegro', 'Ukraine',
#        'Saint Helena', 'Liberia', 'Turkmenistan', 'Niger', 'Sri Lanka',
#        'Trinidad and Tobago', 'United Kingdom', 'Guinea-Bissau',
#        'Micronesia', 'Turkey', 'Croatia', 'Israel',
#        'Svalbard & Jan Mayen Islands', 'Azerbaijan', 'Iran',
#        'Saint Vincent and the Grenadines', 'Bulgaria', 'Christmas Island',
#        'Canada', 'Rwanda', 'Turks and Caicos Islands', 'Norfolk Island',
# ...

# %%
age_ = df.sort_values(["Age"])
age_.head(10)
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 939                     60.83   19     40478.83                185.46
# 730                     65.53   19     51049.47                190.17
# 998                     55.55   19     41920.79                187.95
# 700                     58.60   19     44490.09                197.93
# 349                     60.91   19     53309.61                184.94
# 771                     64.38   19     52530.10                180.47
# 104                     66.49   20     56884.74                202.16
# 891                     54.39   20     52563.22                171.90
# 9                       69.88   20     55642.32                183.82
# 395                     71.05   20     49544.41                204.22
#
#                                    Ad Topic Line               City  Male  \
# 939  Versatile next generation pricing structure         West Lacey     1
# ...

# %%
mean = df.groupby(["Area Income"],as_index = False)["Age"].mean()
mean
# Out:
#      Area Income  Age
# 0       13996.50   41
# 1       14548.06   47
# 2       14775.50   44
# 3       15598.29   45
# 4       15879.10   32
# ..           ...  ...
# 995     78092.95   41
# 996     78119.50   37
# 997     78520.99   41
# 998     79332.33   43
# 999     79484.80   42
#
# [1000 rows x 2 columns]

# %%
mean.columns = ["Area Income","Age"]
mean
# Out:
#      Area Income  Age
# 0       13996.50   41
# 1       14548.06   47
# 2       14775.50   44
# 3       15598.29   45
# 4       15879.10   32
# ..           ...  ...
# 995     78092.95   41
# 996     78119.50   37
# 997     78520.99   41
# 998     79332.33   43
# 999     79484.80   42
#
# [1000 rows x 2 columns]

# %%
new = pd.merge(df,mean,how='inner',on=["Age"])

# %%
new
# Out:
#        Daily Time Spent on Site  Age  Area Income_x  Daily Internet Usage  \
# 0                         68.95   35       61833.90                256.09
# 1                         68.95   35       61833.90                256.09
# 2                         68.95   35       61833.90                256.09
# 3                         68.95   35       61833.90                256.09
# 4                         68.95   35       61833.90                256.09
# ...                         ...  ...            ...                   ...
# 33405                     51.38   59       42362.49                158.56
# 33406                     51.38   59       42362.49                158.56
# 33407                     61.82   59       57877.15                151.93
# 33408                     61.82   59       57877.15                151.93
# 33409                     66.08   61       58966.22                184.23
#
#                                        Ad Topic Line          City  Male  \
# ...

# %%
new.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income_x  Daily Internet Usage  \
# 0                     68.95   35        61833.9                256.09
# 1                     68.95   35        61833.9                256.09
# 2                     68.95   35        61833.9                256.09
# 3                     68.95   35        61833.9                256.09
# 4                     68.95   35        61833.9                256.09
#
#                         Ad Topic Line         City  Male  Country  \
# 0  Cloned 5thgeneration orchestration  Wrightburgh     0  Tunisia
# 1  Cloned 5thgeneration orchestration  Wrightburgh     0  Tunisia
# 2  Cloned 5thgeneration orchestration  Wrightburgh     0  Tunisia
# 3  Cloned 5thgeneration orchestration  Wrightburgh     0  Tunisia
# 4  Cloned 5thgeneration orchestration  Wrightburgh     0  Tunisia
#
#              Timestamp  Clicked on Ad  Area Income_y
# 0  2016-03-27 00:53:11              0       25371.52
# ...

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
left = df.iloc[:1000,:6]
left
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City
# 0       Cloned 5thgeneration orchestration     Wrightburgh
# ...

# %%
right = df.iloc[:500,8:]
right
# Out:
#                Timestamp  Clicked on Ad
# 0    2016-03-27 00:53:11              0
# 1    2016-04-04 01:39:02              0
# 2    2016-03-13 20:35:42              0
# 3    2016-01-10 02:31:19              0
# 4    2016-06-03 03:36:18              0
# ..                   ...            ...
# 495  2016-07-04 11:03:49              0
# 496  2016-07-08 03:47:41              0
# 497  2016-05-27 05:35:27              1
# 498  2016-02-10 13:46:35              0
# 499  2016-06-12 21:21:53              1
#
# [500 rows x 2 columns]

# %%
joined = left.join(right, how='left')
joined
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  \
# 0       Cloned 5thgeneration orchestration     Wrightburgh
# ...

# %%
mean = df.groupby(["Area Income"],as_index = False)["Age"].mean()
mean
# Out:
#      Area Income  Age
# 0       13996.50   41
# 1       14548.06   47
# 2       14775.50   44
# 3       15598.29   45
# 4       15879.10   32
# ..           ...  ...
# 995     78092.95   41
# 996     78119.50   37
# 997     78520.99   41
# 998     79332.33   43
# 999     79484.80   42
#
# [1000 rows x 2 columns]

# %%
sum = df.groupby(["Area Income"],as_index = False)["Age"].sum()
sum
# Out:
#      Area Income  Age
# 0       13996.50   41
# 1       14548.06   47
# 2       14775.50   44
# 3       15598.29   45
# 4       15879.10   32
# ..           ...  ...
# 995     78092.95   41
# 996     78119.50   37
# 997     78520.99   41
# 998     79332.33   43
# 999     79484.80   42
#
# [1000 rows x 2 columns]

# %%
C =pd.concat([mean,sum],axis=1)
C
# Out:
#      Area Income  Age  Area Income  Age
# 0       13996.50   41     13996.50   41
# 1       14548.06   47     14548.06   47
# 2       14775.50   44     14775.50   44
# 3       15598.29   45     15598.29   45
# 4       15879.10   32     15879.10   32
# ..           ...  ...          ...  ...
# 995     78092.95   41     78092.95   41
# 996     78119.50   37     78119.50   37
# 997     78520.99   41     78520.99   41
# 998     79332.33   43     79332.33   43
# 999     79484.80   42     79484.80   42
#
# [1000 rows x 4 columns]

# %%
C.shape
# Out:
# (1000, 4)
